# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

data =pd.read_csv("C:\\Users\\G.B\\Desktop\\المرحلة الاولى\\data science and machine learning\\dataset\\multiTimeline.csv")

data.head()

figure =px.line(data,x="Month",
y="Finance",
title="tim series for twtr"s
)
figure.update_traces(line_color="purple")
figure.show()

# %%
figure =px.bar(data,x="Month",
y="Finance",
title="time serise using bar plot"
# range_x=['2000-2-3','2002-4-5']
)
figure.update_traces(marker_color="black")
figure.show()

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %%
#data.head()
data =pd.read_csv("C:\\Users\\G.B\\Desktop\\المرحلة الاولى\\data science and machine learning\\dataset\\heart_failure_clinical_records_dataset.csv")

# %%
data.info()

# %%
data.describe().round(1)

# %%
data.isna().sum()

# %%
sns.heatmap(data.isna())

# %%
#data['price'].fillna(data['price'].mean())

# %%
data.isna().sum()

# %%
sns.heatmap(data.isna())

# %%
data['sex'].value_counts()

# %%
data['DEATH_EVENT'].value_counts()

# %%
data.head()

# %%
sns.countplot(x='DEATH_EVENT',data=data,hue='DEATH_EVENT')

# %%
data['age'].hist(bins=20)

# %%
data['time'].hist(bins=30)

# %%
data.head()

# %%
c =data.corr()
#print(c)
sns.heatmap(c,annot=True,fmt='0.1f',linewidth=0.5)

# %%
data.plot(figsize=(10,5))
