# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("C:\\Users\\G.B\\Desktop\\المرحلة الاولى\\data science and machine learning\\dataset\\Netflix Userbase.csv")
data.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
data.describe().round(1)

# %%
data.info()

# %%
data.isna()

# %%
data['Subscription Type'].nunique()

# %%
sns.heatmap(data.isna())

# %%
data.head()

# %%
data['Country'].value_counts()

# %%
data['Country'].value_counts().plot.bar()

# %%
data['Gender'].value_counts()
#data['Gender'].value_counts().plot.bar()

# %%
data['Gender'].value_counts().plot.bar()

# %%
data['Device'].value_counts().plot.bar()

# %%
data['Device'].value_counts()

# %%
data.duplicated()

# %%
data.hist(figsize=(20,15))
plt.show()

# %%
c=data.corr()
print(c)

# %%
sns.heatmap(c,annot=True)

# %%
data.head()

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
obj_data=data.select_dtypes(include=["object"])
#print(obj_data)
num_data=data.select_dtypes(exclude=["object"])
for i in range(0,obj_data.shape[1]):
    obj_data.iloc[:,i]=lb.fit_transform(obj_data.iloc[:,i])
data = pd.concat([obj_data,num_data],axis=1)
print(data)

# %%
#print(obj_data)
data = pd.concat([obj_data,num_data],axis=1)
print(data)

# %%
c=data.corr()
sns.heatmap(c,annot=True)

# %%
data.head()

# %%
sns.boxplot(data['Age'])

# %%
data.isnull()

# %%
data.isna()

# %%
data =pd.read_csv("C:\\Users\\G.B\\Desktop\\المرحلة الاولى\\data science and machine learning\\dataset\\Netflix Userbase.csv")
data.head()

# %%
data['Country'].value_counts().plot.pie(labeldistance=1.1 #place of names(where put it)  
,radius=2 # sercal size
,startangle=2,
colors=['red','blue','green','gray'],
rotatelabels=True # for writing (way of writing) 
,autopct='%1.0f%%',figsize=(6,6))
plt.ylabel('')

# %%
data['Gender'].value_counts().plot.hist(
)

# %%
data.head()

# %%
data['Country'].value_counts().plot.bar(color='black',edgecolor='black',facecolor='red',figsize=(2,2))

# %%
data.hist(histtype='bar',
alpha=1,# for color
#color='green',
bins=30 # for count of element
,figsize=(20,15))
plt.show()

# %%
data['Country'].value_counts().plot.pie(labeldistance=0.3 #place of names(where put it)  
,radius=3 # sercal size
,#startangle=0,
colors=['red','blue','green','gray'],
rotatelabels=True # for writing (way of writing) 
,autopct='%1.0f%%')
plt.ylabel('')
plt.title("ali")

# %%
data.head()

# %%
data =pd.read_csv("C:\\Users\\G.B\\Desktop\\المرحلة الاولى\\data science and machine learning\\dataset\\Netflix Userbase.csv")
data.head()

# %%
data.plot(figsize=(10,5))

# %%
import pandas as pd

# %%
data.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
col=list()
suming=0
while(True):
    namevar=input("Enter the name column:")
    if namevar=="done":
         break
    else:
        col.append(namevar)
        for i in range(len(data.columns)):
            if col[0]==data.columns[i]:
                data[namevar].value_counts().plot.bar(color='black',edgecolor='black',facecolor='red',figsize=(4,4))
                plt.show()
               
            else:
                suming=suming+1
                if suming==len(data.columns):
                    print("there not column have this name")
            
                    
                 
    suming-=suming
    col.pop()
# Out:
# Enter the name column:Age
# Enter the name column:Age
# Enter the name column:aa
# there not column have this name
# Enter the name column:sd
# there not column have this name
# Enter the name column:done

# %%
suming
# Out:
# 40

# %%
col
# Out:
# []

# %%
q=[]

# %%
q==[]
# Out:
# True

# %%
q=3

# %%
q
# Out:
# 3

# %%
q-q
# Out:
# 0
