# %%
import keras
# Out:
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense,Activation,BatchNormalization
import tensorflow as tf

from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data =pd.read_csv(R"C:\Users\G.B\Desktop\osam\المرحلة الثانية\data science\dataset\heart_failure_clinical_records_dataset.csv")

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
xtrain,xtemp,ytrain,ytemp=train_test_split(x,y,test_size=0.4)
xtest,xvalid,ytest,yvalid=train_test_split(x,y,test_size=0.5)

# %%
xtrain.shape
# Out:
# (179, 12)

# %%
model = Sequential()
model.add(Dense(64, input_dim=40,activation = "relu")) #Layer 1
model.add(Dense(32,activation = "relu"))  #Layer 2
model.add(Dense(16,activation = "relu"))  #Layer 3
model.add(Dense(8,activation = "relu"))  #Layer 4
model.add(Dense(4,activation = "relu"))  #Layer 5
model.add(Dense(1,activation = "sigmoid"))  #Output Layer
#Configure the model
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                2624
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# ...
# Total params: 5409 (21.13 KB)
# Trainable params: 5409 (21.13 KB)
# ...

# %%
model = tf.keras.Sequential([
tf.keras.layers.Dense(16,activation = "relu",), #Layer 1
tf.keras.layers.Dense(16,activation = "relu"), 
tf.keras.layers.Dense(1,activation = "sigmoid")
])  
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'])

# %%
model.evaluate(xtrain,ytrain)
# Out:
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\G.B\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 2s 12ms/step - loss: 12123.8379 - accuracy: 0.6648
# [12123.837890625, 0.6648044586181641]

# %%
model.fit(xtrain, ytrain, batch_size=64, epochs=10,validation_data=(xvalid,yvalid))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 1s 91ms/step - loss: 11173.6475 - accuracy: 0.6648 - val_loss: 7859.7285 - val_accuracy: 0.6933
# Epoch 2/10
# 3/3 [==============================] - 0s 30ms/step - loss: 8050.1230 - accuracy: 0.6648 - val_loss: 5212.2344 - val_accuracy: 0.6933
# Epoch 3/10
# 3/3 [==============================] - 0s 34ms/step - loss: 5154.2007 - accuracy: 0.6648 - val_loss: 2584.0891 - val_accuracy: 0.6933
# Epoch 4/10
# 3/3 [==============================] - 0s 35ms/step - loss: 1955.8575 - accuracy: 0.6648 - val_loss: 122.3020 - val_accuracy: 0.6933
# Epoch 5/10
# 3/3 [==============================] - 0s 44ms/step - loss: 1334.3495 - accuracy: 0.4860 - val_loss: 3132.5508 - val_accuracy: 0.3067
# Epoch 6/10
# 3/3 [==============================] - 0s 42ms/step - loss: 2913.1729 - accuracy: 0.3352 - val_loss: 2129.9976 - val_accuracy: 0.3067
# Epoch 7/10
# ...

# %%
xtrain
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 275  45.0        0                       582         0                 38
# 29   82.0        0                        70         1                 30
# 287  45.0        0                       582         1                 55
# 176  69.0        0                      1419         0                 40
# 60   45.0        0                      7702         1                 25
# ..    ...      ...                       ...       ...                ...
# 183  75.0        0                        99         0                 38
# 289  90.0        1                       337         0                 38
# 135  75.0        0                       582         0                 40
# 47   60.0        0                       582         1                 38
# 270  44.0        0                       582         1                 30
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
ytrain
# Out:
# 275    0
# 29     1
# 287    0
# 176    0
# 60     1
#       ..
# 183    1
# 289    0
# 135    0
# 47     1
# 270    0
# Name: DEATH_EVENT, Length: 179, dtype: int64

# %%
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 159  59.0        1                       129         0                 45
# 65   60.0        0                        68         0                 20
# 70   41.0        0                       148         0                 40
# 251  55.0        0                       572         1                 35
# 212  78.0        0                       224         0                 50
# ..    ...      ...                       ...       ...                ...
# 261  62.0        1                       655         0                 40
# 275  45.0        0                       582         0                 38
# 75   60.0        1                        47         0                 20
# 151  62.0        0                        30         1                 60
# 182  65.0        0                       395         1                 25
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 276  70.0        0                       618         0                 35
# 125  43.0        1                       358         0                 50
# 2    65.0        0                       146         0                 20
# 46   51.0        0                      1380         0                 25
# 167  59.0        0                        66         1                 20
# ..    ...      ...                       ...       ...                ...
# 113  70.0        1                       143         0                 60
# 44   60.0        1                       588         1                 60
# 3    50.0        1                       111         0                 20
# 228  65.0        0                        56         0                 25
# 181  59.0        1                       176         1                 25
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
ytest
# Out:
# 159    0
# 65     1
# 70     0
# 251    0
# 212    0
#       ..
# 261    0
# 275    0
# 75     1
# 151    0
# 182    1
# Name: DEATH_EVENT, Length: 149, dtype: int64

# %%
model.predict(xtest)
# Out:
# 5/5 [==============================] - 0s 2ms/step
# array([[0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [3.525375e-30],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
#        [0.000000e+00],
# ...

# %%
model.predict([[45.0, 0 ,582, 0, 38, 1, 422000.00, 0.80, 137, 0 ,0 ,245]])
# Out:
# 1/1 [==============================] - 0s 152ms/step
# array([[0.]], dtype=float32)

# %%
# Sequential mean layers
model =Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(179,179,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))


model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 177, 177, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 88, 88, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 86, 86, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 9, 9, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense_9 (Dense)             (None, 512)               5308928
#
#  dense_10 (Dense)            (None, 1)                 513
#
# ...
# Total params: 5550273 (21.17 MB)
# Trainable params: 5550273 (21.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...
