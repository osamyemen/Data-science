# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("C:\\Users\\G.B\\Desktop\\Data science\\dataset\\austin_weather.csv")
data.head()

# %%
data.drop('Events',axis=1)

# %%
data.describe().round(1)

# %%
data.info()

# %%
data.value_counts().sum()

# %%
data.isna().sum

# %%
data.head()

# %%
data['Events'].value_counts()

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
figure =px.line(data,x="Date",
y="TempHighF",
title="tim series for twtr"
)
figure.update_traces(line_color="purple")
figure.show()

# %%
figure =px.line(data,x="Date",
y="TempLowF",
title="tim series for twtr"
)
figure.update_traces(line_color="purple")
figure.show()

# %%
data.head()

# %%
figure =go.Figure(data=[go.Candlestick(x=data["Date"],
open=data["DewPointAvgF"],
high=data["TempHighF"],
low=data["TempLowF"],
close=data["HumidityHighPercent"])])
figure.update_layout(title="time serise using candlestick",
xaxis_rangeslider_visible=False)
figure.show()

# %%
data.head()
