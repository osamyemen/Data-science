# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(R"dataset/titanic.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %% [markdown]
# ### columns in data in number

# %%
print(df.columns)
print("----------------------------")
print("the number of columns acount:",len(df.columns))
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# ----------------------------
# the number of columns acount: 16

# %% [markdown]
# ### The column values and number

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print(df['sex'].unique())
print("------------------------------------------------")
print("the number:",df['sex'].nunique())
# Out:
# ['male' 'female']
# ------------------------------------------------
# the number: 2

# %% [markdown]
# ### null and non values in columns

# %%
df.isna().any()
# Out:
# Unnamed: 0     False
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
df.isnull().sum()
df.isna().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Unnamed: 0     891
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### duplicated data

# %%
#data.duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(subset=['sex'])].head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
# 5           5         0       3    male   NaN      0      0   8.4583        Q
# 6           6         0       1    male  54.0      0      0  51.8625        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True
# 5  Third    man        True  NaN   Queenstown    no   True
# 6  First    man        True    E  Southampton    no   True

# %% [markdown]
# ### get all columns that is empty

# %%
df0 = df==0

# %%
df0
# Out:
#      Unnamed: 0  survived  pclass    sex    age  sibsp  parch   fare  \
# 0          True      True   False  False  False  False   True  False
# 1         False     False   False  False  False  False   True  False
# 2         False     False   False  False  False   True   True  False
# 3         False     False   False  False  False  False   True  False
# 4         False      True   False  False  False   True   True  False
# ..          ...       ...     ...    ...    ...    ...    ...    ...
# 886       False      True   False  False  False   True   True  False
# 887       False     False   False  False  False   True   True  False
# 888       False      True   False  False  False  False  False  False
# 889       False     False   False  False  False   True   True  False
# 890       False      True   False  False  False   True   True  False
#
#      embarked  class    who  adult_male   deck  embark_town  alive  alone
# ...

# %%
zero = df0.iloc[:,1:].all(axis=1)

# %%
sum(zero)
# Out:
# 0

# %% [markdown]
# # outliers قيم شاذة

# %%
df.plot(subplots=True ,figsize=(20,10))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
df['fare'].plot()
# Out:
# <Axes: >

# %%
df.boxplot('fare')
# Out:
# <Axes: >
