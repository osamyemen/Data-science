# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# Regression
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
# Classifiction
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel(R"C:\Users\G.B\Desktop\osam\المرحلة الثانية\data science\dataset\cleaner.xlsx")

# %%
data.head()
# Out:
#    ss       Open       High        Low  Close  Adj Close  Volume
# 0   0  45.590000  49.840000  45.020000    NaN  49.139999     NaN
# 1   1  48.900002  52.580002  48.700001    NaN  51.990002     NaN
# 2   2  52.400002  53.869999  51.000000    NaN  52.340000     NaN
# 3   3  52.200001  55.869999  50.689999    NaN  55.330002     NaN
# 4   4  56.200001  59.410000  55.450001    NaN  59.000000     NaN

# %%
data = data.drop(["ss","Adj Close","Volume"],axis=1)

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
s = 2
type(s)==float
# Out:
# False

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=40)

# %%
y
# Out:
# 99      39.020000
# 100     38.750000
# 101     31.850000
# 102     30.660000
# 103     31.959999
#           ...
# 2233    49.889999
# 2234    51.520000
# 2235    52.779999
# 2236    53.349998
# 2237    53.700001
# Name: Close, Length: 2139, dtype: float64

# %%
model0=LinearRegression()
model1=MLPRegressor(activation='tanh',max_iter=1000)
model2=DecisionTreeRegressor(max_depth=1000)
model3=RandomForestRegressor(n_estimators=1000,max_depth=1000)
model4=KNeighborsRegressor(n_neighbors=10)
#-------------------------------
model0.fit(x_train,y_train)
model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
model3.fit(x_train,y_train)
model4.fit(x_train,y_train)
#-------------------------------
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
print(model0.score(x_train,y_train))
print(model1.score(x_train,y_train))
print(model2.score(x_train,y_train))
print(model3.score(x_train,y_train))
print(model4.score(x_train,y_train))
# Out:
# 0.9991053881981695
# 0.9938684622546047
# 1.0
# 0.9997744842934617
# 0.998615609846533

# %%
#--------------------------------------
print(model0.score(x_test,y_test))
print(model1.score(x_test,y_test))
print(model2.score(x_test,y_test))
print(model3.score(x_test,y_test))
print(model4.score(x_test,y_test))
# Out:
# 0.9992740062460923
# 0.993611133394487
# 0.9980069322398746
# 0.9988929780360287
# 0.9988086570133182

# %%
x_test
# Out:
#            Open       High        Low
# 990   20.160000  20.305000  19.930000
# 876   18.530001  18.580000  18.219999
# 1651  30.150000  31.170000  30.059999
# 1018  25.030001  25.270000  24.379999
# 525   20.120001  20.200001  19.260000
# ...         ...        ...        ...
# 2046  34.220001  34.990002  33.619999
# 2224  49.660000  50.860001  49.500000
# 383   34.630001  35.040001  34.450001
# 450   26.969999  27.280001  26.575001
# 2083  37.459999  39.044998  37.180000
#
# [535 rows x 3 columns]

# %%
y_test
# Out:
# 990     20.170000
# 876     18.309999
# 1651    30.809999
# 1018    24.459999
# 525     19.650000
#           ...
# 2046    34.169998
# 2224    50.360001
# 383     34.660000
# 450     26.790001
# 2083    37.770000
# Name: Close, Length: 535, dtype: float64

# %%
model3.predict(x_test)
# Out:
# array([20.13154025, 18.39319018, 30.59343996, 24.80535969, 19.60185018,
#        50.56288964, 17.33220015, 39.02501953, 48.71469032, 32.75378963,
#        42.40761092, 29.96211981, 14.29377   , 46.40600938, 29.96571962,
#        48.57923092, 33.12906938, 41.71104977, 17.88847047, 63.38604935,
#        28.30958011, 33.17063962, 35.88724955, 36.88220009, 39.30229032,
#        35.11396929, 26.46946979, 27.95619018, 44.01241059, 17.45042069,
#        24.70772014, 33.02769935, 39.71050947, 30.25956962, 31.24173955,
#        40.40256006, 35.32801999, 37.73423007, 17.85225032, 18.25360979,
#        32.96481988, 24.04297996, 39.29382999, 60.89311028, 16.91714991,
#        35.13976935, 33.66717023, 17.6236101 , 48.97024062, 47.93253   ,
#        19.04200009, 33.78514082, 40.48087972, 37.15918025, 15.06195   ,
#        34.15303058, 35.82904986, 29.20567965, 35.98880024, 35.95956971,
#        14.69532   , 38.30818028, 23.12730983, 37.62062022, 43.68389112,
# ...

# %%
data1 = pd.read_excel(R"C:\Users\G.B\Desktop\osam\المرحلة الثانية\data science\dataset\nullclean.xlsx")

# %%
data1
# Out:
#          Open       High        Low  Close
# 0   45.590000  49.840000  45.020000    NaN
# 1   48.900002  52.580002  48.700001    NaN
# 2   52.400002  53.869999  51.000000    NaN
# 3   52.200001  55.869999  50.689999    NaN
# 4   56.200001  59.410000  55.450001    NaN
# ..        ...        ...        ...    ...
# 94  44.290001  44.439999  41.310001    NaN
# 95  41.759998  42.349998  39.299999    NaN
# 96  40.529999  43.970001  40.174999    NaN
# 97  37.660000  38.980000  37.240002    NaN
# 98  39.009998  40.770000  38.966000    NaN
#
# [99 rows x 4 columns]

# %%
data1 = data1.drop(["Close"],axis=1)

# %%
data1
# Out:
#          Open       High        Low
# 0   45.590000  49.840000  45.020000
# 1   48.900002  52.580002  48.700001
# 2   52.400002  53.869999  51.000000
# 3   52.200001  55.869999  50.689999
# 4   56.200001  59.410000  55.450001
# ..        ...        ...        ...
# 94  44.290001  44.439999  41.310001
# 95  41.759998  42.349998  39.299999
# 96  40.529999  43.970001  40.174999
# 97  37.660000  38.980000  37.240002
# 98  39.009998  40.770000  38.966000
#
# [99 rows x 3 columns]

# %%
model3.predict(data1)
# Out:
# array([48.06011029, 51.22677018, 52.24982054, 51.93228053, 57.28545914,
#        58.08767011, 56.75151961, 55.56811939, 56.17067998, 59.06310082,
#        62.56422967, 67.76890942, 71.44203923, 66.06013032, 61.39415028,
#        63.55844948, 66.29962021, 69.40914872, 65.82225021, 65.90624798,
#        59.20944047, 58.31395979, 57.61214913, 58.77729001, 58.62745042,
#        60.69460069, 61.96916069, 62.93668033, 62.13102978, 62.63056011,
#        61.95867076, 62.56284031, 59.25658003, 58.76270995, 59.69790982,
#        64.26341983, 64.28176853, 65.00788941, 65.07499961, 65.7977804 ,
#        52.21813001, 52.35618003, 53.72253032, 53.8287407 , 56.32100023,
#        57.04747895, 57.18362967, 57.73629012, 57.6603598 , 56.19267026,
#        56.85892934, 56.3094994 , 55.77490949, 56.22599008, 56.3604294 ,
#        54.51319967, 53.6396611 , 54.42821062, 54.19445118, 56.15418977,
#        54.31439103, 53.77888074, 54.18947059, 54.23064081, 54.3092809 ,
# ...

# %%
data2 = pd.read_csv(R"C:\Users\G.B\Desktop\osam\المرحلة الثانية\data science\dataset\TWTR.csv")

# %%
data2["Close"].head(7)
# Out:
# 0    49.139999
# 1    51.990002
# 2    52.340000
# 3    55.330002
# 4    59.000000
# 5    56.610001
# 6    56.450001
# Name: Close, dtype: float64
